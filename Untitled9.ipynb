# %% [markdown]
# <a href="https://colab.research.google.com/github/PotlachervuSrilatha/PYTHON/blob/main/Untitled9.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("/content/Advertising.csv")

# %%
df
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 0             1  230.1   37.8       69.2   22.1
# 1             2   44.5   39.3       45.1   10.4
# 2             3   17.2   45.9       69.3    9.3
# 3             4  151.5   41.3       58.5   18.5
# 4             5  180.8   10.8       58.4   12.9
# ..          ...    ...    ...        ...    ...
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4
#
# [200 rows x 5 columns]

# %%
df.head()
# Out:
#    Unnamed: 0     TV  Radio  Newspaper  Sales
# 0           1  230.1   37.8       69.2   22.1
# 1           2   44.5   39.3       45.1   10.4
# 2           3   17.2   45.9       69.3    9.3
# 3           4  151.5   41.3       58.5   18.5
# 4           5  180.8   10.8       58.4   12.9

# %%
df.tail()
# Out:
#      Unnamed: 0     TV  Radio  Newspaper  Sales
# 195         196   38.2    3.7       13.8    7.6
# 196         197   94.2    4.9        8.1    9.7
# 197         198  177.0    9.3        6.4   12.8
# 198         199  283.6   42.0       66.2   25.5
# 199         200  232.1    8.6        8.7   13.4

# %%
df.shape
# Out:
# (200, 5)

# %%
df.drop(["Unnamed: 0"],inplace=True,axis=1)

# %%
df.columns
# Out:
# Index(['TV', 'Radio', 'Newspaper', 'Sales'], dtype='object')

# %%
df.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
df.duplicated()
# Out:
# 0

# %%
df.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
df.corr()
# Out:
#                  TV     Radio  Newspaper     Sales
# TV         1.000000  0.054809   0.056648  0.782224
# Radio      0.054809  1.000000   0.354104  0.576223
# Newspaper  0.056648  0.354104   1.000000  0.228299
# Sales      0.782224  0.576223   0.228299  1.000000

# %%
sns.scatterplot(df["Radio"])
# Out:
# <Axes: ylabel='Radio'>

# %%
sns.scatterplot(df["TV"])
# Out:
# <Axes: ylabel='TV'>

# %%
sns.scatterplot(df["Newspaper"])
# Out:
# <Axes: ylabel='Newspaper'>

# %%
sns.scatterplot(df["Sales"])
# Out:
# <Axes: ylabel='Sales'>

# %%
sns.scatterplot(x="TV",
                y="Sales",
                data=df)
# Out:
# <Axes: xlabel='TV', ylabel='Sales'>

# %%
sns.scatterplot(x="Radio",
                y="Sales",
                data=df)
# Out:
# <Axes: xlabel='Radio', ylabel='Sales'>

# %%
sns.scatterplot(x="Newspaper",
                y="Sales",
                data=df)
# Out:
# <Axes: xlabel='Newspaper', ylabel='Sales'>

# %%
sns.distplot(df["TV"])
# Out:
# <ipython-input-56-9f1e8791b6f9>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df["TV"])
# <Axes: xlabel='TV', ylabel='Density'>

# %%
sns.distplot(df['Newspaper'])
# Out:
# <ipython-input-46-6fe4fcc6000a>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Newspaper'])
# <Axes: xlabel='Newspaper', ylabel='Density'>

# %%
sns.distplot(df['Radio'])
# Out:
# <ipython-input-54-6a0fc54c08d4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Radio'])
# <Axes: xlabel='Radio', ylabel='Density'>

# %%
sns.distplot(df['Sales'])
# Out:
# <ipython-input-55-87032c1a53f4>:1: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['Sales'])
# <Axes: xlabel='Sales', ylabel='Density'>

# %%
plt.hist(df['Newspaper'])
# Out:
# (array([47., 41., 35., 30., 21., 13.,  9.,  2.,  1.,  1.]),
#  array([  0.3 ,  11.67,  23.04,  34.41,  45.78,  57.15,  68.52,  79.89,
#          91.26, 102.63, 114.  ]),
#  <BarContainer object of 10 artists>)

# %%
plt.hist(df)
plt.show()

# %%
plt.bar(df['Radio'],
        df['Sales'])
# Out:
# <BarContainer object of 200 artists>
